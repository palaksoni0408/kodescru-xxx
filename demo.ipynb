# %%
pip install euriai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: euriai in c:\users\palak\appdata\roaming\python\python313\site-packages (0.3.30)
# Requirement already satisfied: requests in c:\users\palak\appdata\roaming\python\python313\site-packages (from euriai) (2.32.3)
# Requirement already satisfied: langchain-core in c:\users\palak\appdata\roaming\python\python313\site-packages (from euriai) (0.3.66)
# Requirement already satisfied: llama-index>=0.10.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from euriai) (0.12.44)
# Requirement already satisfied: numpy in c:\users\palak\appdata\roaming\python\python313\site-packages (from euriai) (2.2.6)
# Requirement already satisfied: llama-index-agent-openai<0.5,>=0.4.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index>=0.10.0->euriai) (0.4.11)
# Requirement already satisfied: llama-index-cli<0.5,>=0.4.2 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index>=0.10.0->euriai) (0.4.3)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.44 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index>=0.10.0->euriai) (0.12.44)
# Requirement already satisfied: llama-index-embeddings-openai<0.4,>=0.3.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index>=0.10.0->euriai) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index>=0.10.0->euriai) (0.7.7)
# Requirement already satisfied: llama-index-llms-openai<0.5,>=0.4.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index>=0.10.0->euriai) (0.4.7)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.6,>=0.5.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index>=0.10.0->euriai) (0.5.1)
# Requirement already satisfied: llama-index-program-openai<0.4,>=0.3.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index>=0.10.0->euriai) (0.3.2)
# Requirement already satisfied: llama-index-question-gen-openai<0.4,>=0.3.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index>=0.10.0->euriai) (0.3.1)
# Requirement already satisfied: llama-index-readers-file<0.5,>=0.4.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index>=0.10.0->euriai) (0.4.9)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index>=0.10.0->euriai) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index>=0.10.0->euriai) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-agent-openai<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (1.92.2)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (3.12.13)
# Requirement already satisfied: aiosqlite in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (2.1.3)
# Requirement already satisfied: dataclasses-json in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (2025.5.1)
# Requirement already satisfied: httpx in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (0.28.1)
# Requirement already satisfied: llama-index-workflows<2,>=1.0.1 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (1.0.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (3.5)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (2.11.7)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (6.0.2)
# Requirement already satisfied: setuptools>=80.9.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in c:\users\palak\appdata\roaming\python\python313\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (2.0.41)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (4.13.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\palak\appdata\roaming\python\python313\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\palak\appdata\roaming\python\python313\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\palak\appdata\roaming\python\python313\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (6.6.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (1.20.1)
# Requirement already satisfied: griffe in c:\users\palak\appdata\roaming\python\python313\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (1.7.3)
# Requirement already satisfied: jinja2 in c:\users\palak\appdata\roaming\python\python313\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (3.1.6)
# Requirement already satisfied: platformdirs in c:\users\palak\appdata\roaming\python\python313\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (4.3.8)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (4.13.4)
# Requirement already satisfied: pandas<2.3.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (2.2.3)
# Requirement already satisfied: pypdf<6,>=5.1.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (5.6.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (0.0.26)
# Requirement already satisfied: soupsieve>1.2 in c:\users\palak\appdata\roaming\python\python313\site-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (2.7)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-workflows<2,>=1.0.1->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (0.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\palak\appdata\roaming\python\python313\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\palak\appdata\roaming\python\python313\site-packages (from anyio<5,>=3.5.0->openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (3.10)
# Requirement already satisfied: certifi in c:\users\palak\appdata\roaming\python\python313\site-packages (from httpx->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\palak\appdata\roaming\python\python313\site-packages (from httpx->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\palak\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\palak\appdata\roaming\python\python313\site-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\palak\appdata\roaming\python\python313\site-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\palak\appdata\roaming\python\python313\site-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\palak\appdata\roaming\python\python313\site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (0.4.1)
# Requirement already satisfied: colorama in c:\users\palak\appdata\roaming\python\python313\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (0.4.6)
# Requirement already satisfied: llama-cloud==0.1.26 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index>=0.10.0->euriai) (0.1.26)
# Requirement already satisfied: llama-parse>=0.5.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index>=0.10.0->euriai) (0.6.34)
# Requirement already satisfied: llama-cloud-services>=0.6.32 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index>=0.10.0->euriai) (0.6.34)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-cloud-services>=0.6.32->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index>=0.10.0->euriai) (8.2.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in c:\users\palak\appdata\roaming\python\python313\site-packages (from llama-cloud-services>=0.6.32->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index>=0.10.0->euriai) (1.1.1)
# Requirement already satisfied: joblib in c:\users\palak\appdata\roaming\python\python313\site-packages (from nltk>3.8.1->llama-index>=0.10.0->euriai) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\palak\appdata\roaming\python\python313\site-packages (from nltk>3.8.1->llama-index>=0.10.0->euriai) (2024.11.6)
# Requirement already satisfied: six>=1.5 in c:\users\palak\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.10.0->euriai) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\palak\appdata\roaming\python\python313\site-packages (from requests->euriai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\palak\appdata\roaming\python\python313\site-packages (from requests->euriai) (2.4.0)
# Requirement already satisfied: greenlet>=1 in c:\users\palak\appdata\roaming\python\python313\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from dataclasses-json->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.44->llama-index>=0.10.0->euriai) (3.0.2)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\palak\appdata\roaming\python\python313\site-packages (from langchain-core->euriai) (0.4.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\palak\appdata\roaming\python\python313\site-packages (from langchain-core->euriai) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\palak\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0,>=1.33->langchain-core->euriai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\palak\appdata\roaming\python\python313\site-packages (from langsmith>=0.3.45->langchain-core->euriai) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from langsmith>=0.3.45->langchain-core->euriai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\palak\appdata\roaming\python\python313\site-packages (from langsmith>=0.3.45->langchain-core->euriai) (0.23.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from euriai import EuriaiClient
import os 
from dotenv import load_dotenv 
load_dotenv()
api_key = os.getenv("EURIAI_API_KEY") 

client = EuriaiClient(
    api_key=api_key,
    model="gpt-4.1-nano" 
)

response = client.generate_completion(
    prompt="Write a short poem about artificial intelligence.",
    temperature=0.7,
    max_tokens=300
)

print(response['choices'][0]['message']['content'])
# Out:
# In circuits woven, silent and bright,
# Artificial minds ignite,
# Learning whispers through the code,
# A spark of thought where once was mode.
#
# Born from human dreams and schemes,
# A mirror of our hopes and means,
# Guiding us with unseen hand,
# A future shaped by thought so grand.
